# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d rohanrao/nifty50-stock-market-data
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading nifty50-stock-market-data.zip to /content
#   0% 0.00/18.4M [00:00<?, ?B/s]
# 100% 18.4M/18.4M [00:00<00:00, 210MB/s]

# %%
from zipfile import ZipFile
dataset = '/content/nifty50-stock-market-data.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import datetime as dt


from tensorflow.keras.layers import Dense, Dropout
from keras.layers import GRU
from keras.models import Sequential, load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
main_dataset1 = pd.read_csv("/content/SUNPHARMA.csv") #Read the data

# %%
main_dataset1.head()
# Out:
#          Date     Symbol Series  Prev Close    Open     High     Low     Last  \
# 0  2000-01-03  SUNPHARMA     EQ     1699.10  1800.0  1835.05  1760.0  1835.05
# 1  2000-01-04  SUNPHARMA     EQ     1835.05  1960.0  1960.00  1763.0  1811.50
# 2  2000-01-05  SUNPHARMA     EQ     1810.45  1845.0  1845.00  1740.0  1745.00
# 3  2000-01-06  SUNPHARMA     EQ     1746.90  1750.0  1795.00  1735.0  1748.00
# 4  2000-01-07  SUNPHARMA     EQ     1745.20  1705.0  1705.00  1605.6  1605.60
#
#      Close     VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  1835.05  1825.90    3024  5.521525e+11     NaN                 NaN
# 1  1810.45  1805.97    5787  1.045115e+12     NaN                 NaN
# 2  1746.90  1766.69    6105  1.078564e+12     NaN                 NaN
# 3  1745.20  1749.32    3472  6.073632e+11     NaN                 NaN
# 4  1605.60  1621.51    4125  6.688740e+11     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Extracting date and total confirmed cases columns
date_column = 'Date'  # Assuming 'Date' is the column name for date
Turnover = 'Turnover'  # Assuming 'Total Confirmed cases' is the column name for confirmed cases

# Selecting only the columns of interest
main_dataset = main_dataset1[[date_column,Turnover ]]

# Displaying the selected data
print(main_dataset)
# Out:
#             Date      Turnover
# 0     2000-01-03  5.521525e+11
# 1     2000-01-04  1.045115e+12
# 2     2000-01-05  1.078564e+12
# 3     2000-01-06  6.073632e+11
# 4     2000-01-07  6.688740e+11
# ...          ...           ...
# 5301  2021-04-26  4.142697e+14
# 5302  2021-04-27  3.255177e+14
# 5303  2021-04-28  3.901097e+14
# 5304  2021-04-29  3.668690e+14
# 5305  2021-04-30  7.132852e+14
#
# [5306 rows x 2 columns]

# %%
main_dataset['Turnover'] = main_dataset['Turnover'].astype(int)
# Out:
# <ipython-input-52-4bbeb94d8ede>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_dataset['Turnover'] = main_dataset['Turnover'].astype(int)

# %%
main_dataset1.head()
# Out:
#          Date     Symbol Series  Prev Close    Open     High     Low     Last  \
# 0  2000-01-03  SUNPHARMA     EQ     1699.10  1800.0  1835.05  1760.0  1835.05
# 1  2000-01-04  SUNPHARMA     EQ     1835.05  1960.0  1960.00  1763.0  1811.50
# 2  2000-01-05  SUNPHARMA     EQ     1810.45  1845.0  1845.00  1740.0  1745.00
# 3  2000-01-06  SUNPHARMA     EQ     1746.90  1750.0  1795.00  1735.0  1748.00
# 4  2000-01-07  SUNPHARMA     EQ     1745.20  1705.0  1705.00  1605.6  1605.60
#
#      Close     VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  1835.05  1825.90    3024  5.521525e+11     NaN                 NaN
# 1  1810.45  1805.97    5787  1.045115e+12     NaN                 NaN
# 2  1746.90  1766.69    6105  1.078564e+12     NaN                 NaN
# 3  1745.20  1749.32    3472  6.073632e+11     NaN                 NaN
# 4  1605.60  1621.51    4125  6.688740e+11     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
main_dataset
# Out:
#             Date         Turnover
# 0     2000-01-03     552152475000
# 1     2000-01-04    1045115490000
# 2     2000-01-05    1078563995000
# 3     2000-01-06     607363240000
# 4     2000-01-07     668874015000
# ...          ...              ...
# 5301  2021-04-26  414269652730000
# 5302  2021-04-27  325517675070000
# 5303  2021-04-28  390109664680000
# 5304  2021-04-29  366869016650000
# 5305  2021-04-30  713285177650000
#
# [5306 rows x 2 columns]

# %%
main_dataset = main_dataset.rename(columns={'Turnover': 'TO'})

# %%
plt.plot(main_dataset.Date,main_dataset.TO)
plt.show()

# %%
dataset = main_dataset #Create another dataset same as the main dataset. Just to avoid replacing the main one.
dataset = dataset.set_index('Date') #Set the index of the dataset as the date
dataset = dataset['TO'] #We will be left with only one column Cases for our dataset

# %%
dataset=dataset.to_frame() #Convert the Series into a dataframe object
dataset['TO_AVG']=dataset.expanding(min_periods=3).mean()  #min_periods is used to set the no. of periods for calculating MA. Mean is for calculating average.

# %%
dataset['EMA'] = dataset.iloc[:,0].ewm(span=3,adjust=False).mean() #ewm is used exponential moving average

# %%
dataset = dataset[dataset['TO_AVG'].notna()] #Remove the rows that have NAs

# %%
dataset.head()
# Out:
#                        TO        TO_AVG           EMA
# Date
# 2000-01-05  1078563995000  8.919440e+11  9.385990e+11
# 2000-01-06   607363240000  8.207988e+11  7.729811e+11
# 2000-01-07   668874015000  7.904138e+11  7.209276e+11
# 2000-01-10   692504815000  7.740957e+11  7.067162e+11
# 2000-01-11  4199903715000  1.263497e+12  2.453310e+12

# %%
#Cases is the column we have to predict.
target=dataset[['TO']]
del dataset['TO']

# %%
x, y = dataset.values, target.values

# %%
x.shape
# Out:
# (5304, 2)

# %%
y.shape
# Out:
# (5304, 1)

# %%
x_scaled_set = MinMaxScaler() #Use MinMaxScaler function from sklearn.preprocessing library
y_scaled_set = MinMaxScaler()

X = x_scaled_set.fit_transform(x) #Fit to data and transform the data array x
Y = y_scaled_set.fit_transform(y.reshape(-1,1)) #Fit to data and transform the data array y. Reshape the y variable to long format

# %%
x.shape
# Out:
# (5303, 2)

# %%
X_train_data=X[0:5100,]
y_train_data=Y[0:5100,]
X_test_data=X[5100:5303,]
y_test_data=Y[5100:5303,]

# %%
X_train_data.shape
# Out:
# (5100, 2)

# %%
y_test_data.shape
# Out:
# (203, 1)

# %%
X_train_data = X_train_data.reshape((-1,1,2)) #Reshape train dataset to required format
X_test_data = X_test_data.reshape((-1,1,2)) #Reshape test dataset to required format

# %%
GRU_model = Sequential() #Use Sequential function from keras.model library
GRU_model.add(GRU(units=512,
              return_sequences=True,
              input_shape=(1, 2))) #Add GRU model with 512 units. Note that return sequences should be true to pass on the sequences. Ensure that input_shape is inline with the inout data.
GRU_model.add(Dropout(0.2)) #Add a dropout layer to avoid overfitting.
GRU_model.add(GRU(units=256)) #Add another GRU layer with 256 units.
GRU_model.add(Dropout(0.2)) #Add another dropout layer to avoid overfitting.
GRU_model.add(Dense(1, activation='sigmoid')) #Finally, add a dense layer for getting a fully connected layer.

# %%
GRU_model.compile(loss='mse', optimizer='adam', metrics = ['accuracy']) #mse is mean square error which is the loss function and Adam optimizer will be the ooptimizer.

# %%
GRU_model.fit(X_train_data,y_train_data,batch_size=250, epochs=50, validation_split=0.8, verbose=1)
#GRU_model.save("covid_GRU.h5") #Save the model if you want for reuse.
# Out:
# Epoch 1/50
# 5/5 [==============================] - 7s 364ms/step - loss: 0.2398 - accuracy: 9.8135e-04 - val_loss: 0.1959 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.1885 - accuracy: 9.8135e-04 - val_loss: 0.1167 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 5/5 [==============================] - 1s 141ms/step - loss: 0.1079 - accuracy: 9.8135e-04 - val_loss: 0.0384 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0350 - accuracy: 9.8135e-04 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0061 - accuracy: 9.8135e-04 - val_loss: 9.3315e-04 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 5/5 [==============================] - 1s 214ms/step - loss: 8.9418e-04 - accuracy: 9.8135e-04 - val_loss: 4.1656e-04 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 5/5 [==============================] - 1s 214ms/step - loss: 1.7760e-04 - accuracy: 9.8135e-04 - val_loss: 3.5800e-04 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 5/5 [==============================] - 1s 225ms/step - loss: 5.5999e-05 - accuracy: 9.8135e-04 - val_loss: 3.4974e-04 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 5/5 [==============================] - 1s 133ms/step - loss: 2.5211e-05 - accuracy: 9.8135e-04 - val_loss: 3.4856e-04 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.5585e-05 - accuracy: 9.8135e-04 - val_loss: 3.4854e-04 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 5/5 [==============================] - 1s 137ms/step - loss: 1.1089e-05 - accuracy: 9.8135e-04 - val_loss: 3.4869e-04 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 5/5 [==============================] - 1s 133ms/step - loss: 8.8582e-06 - accuracy: 9.8135e-04 - val_loss: 3.4883e-04 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 5/5 [==============================] - 1s 151ms/step - loss: 7.6756e-06 - accuracy: 9.8135e-04 - val_loss: 3.4892e-04 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 5/5 [==============================] - 1s 265ms/step - loss: 7.0520e-06 - accuracy: 9.8135e-04 - val_loss: 3.4899e-04 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 5/5 [==============================] - 1s 247ms/step - loss: 6.6782e-06 - accuracy: 9.8135e-04 - val_loss: 3.4903e-04 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 5/5 [==============================] - 1s 226ms/step - loss: 6.3868e-06 - accuracy: 9.8135e-04 - val_loss: 3.4906e-04 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 5/5 [==============================] - 1s 215ms/step - loss: 6.2333e-06 - accuracy: 9.8135e-04 - val_loss: 3.4908e-04 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 5/5 [==============================] - 1s 142ms/step - loss: 6.1255e-06 - accuracy: 9.8135e-04 - val_loss: 3.4910e-04 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 5/5 [==============================] - 1s 225ms/step - loss: 6.0816e-06 - accuracy: 9.8135e-04 - val_loss: 3.4911e-04 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 5/5 [==============================] - 1s 227ms/step - loss: 6.1206e-06 - accuracy: 9.8135e-04 - val_loss: 3.4912e-04 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 5/5 [==============================] - 1s 226ms/step - loss: 6.0041e-06 - accuracy: 9.8135e-04 - val_loss: 3.4913e-04 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 5/5 [==============================] - 1s 140ms/step - loss: 6.0314e-06 - accuracy: 9.8135e-04 - val_loss: 3.4914e-04 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 5/5 [==============================] - 1s 216ms/step - loss: 5.9039e-06 - accuracy: 9.8135e-04 - val_loss: 3.4915e-04 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 5/5 [==============================] - 1s 141ms/step - loss: 5.8600e-06 - accuracy: 9.8135e-04 - val_loss: 3.4916e-04 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 5/5 [==============================] - 1s 215ms/step - loss: 5.7090e-06 - accuracy: 9.8135e-04 - val_loss: 3.4916e-04 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 5/5 [==============================] - 1s 136ms/step - loss: 5.8481e-06 - accuracy: 9.8135e-04 - val_loss: 3.4917e-04 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 5/5 [==============================] - 1s 223ms/step - loss: 5.5446e-06 - accuracy: 9.8135e-04 - val_loss: 3.4918e-04 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 5/5 [==============================] - 1s 161ms/step - loss: 5.7409e-06 - accuracy: 9.8135e-04 - val_loss: 3.4919e-04 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 5/5 [==============================] - 1s 262ms/step - loss: 5.7005e-06 - accuracy: 9.8135e-04 - val_loss: 3.4920e-04 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 5/5 [==============================] - 1s 219ms/step - loss: 5.7211e-06 - accuracy: 9.8135e-04 - val_loss: 3.4921e-04 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 5/5 [==============================] - 1s 255ms/step - loss: 5.6382e-06 - accuracy: 9.8135e-04 - val_loss: 3.4921e-04 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 5/5 [==============================] - 1s 144ms/step - loss: 5.6911e-06 - accuracy: 9.8135e-04 - val_loss: 3.4922e-04 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 5/5 [==============================] - 1s 139ms/step - loss: 5.6326e-06 - accuracy: 9.8135e-04 - val_loss: 3.4923e-04 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 5/5 [==============================] - 1s 140ms/step - loss: 5.4997e-06 - accuracy: 9.8135e-04 - val_loss: 3.4924e-04 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 5/5 [==============================] - 1s 136ms/step - loss: 5.7323e-06 - accuracy: 9.8135e-04 - val_loss: 3.4925e-04 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 5/5 [==============================] - 1s 216ms/step - loss: 5.5106e-06 - accuracy: 9.8135e-04 - val_loss: 3.4926e-04 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 5/5 [==============================] - 1s 222ms/step - loss: 5.4206e-06 - accuracy: 9.8135e-04 - val_loss: 3.4927e-04 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 5/5 [==============================] - 1s 272ms/step - loss: 5.2492e-06 - accuracy: 9.8135e-04 - val_loss: 3.4928e-04 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 5/5 [==============================] - 1s 299ms/step - loss: 5.2604e-06 - accuracy: 9.8135e-04 - val_loss: 3.4929e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 5/5 [==============================] - 1s 251ms/step - loss: 5.2809e-06 - accuracy: 9.8135e-04 - val_loss: 3.4930e-04 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 5/5 [==============================] - 1s 140ms/step - loss: 5.2912e-06 - accuracy: 9.8135e-04 - val_loss: 3.4931e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 5/5 [==============================] - 1s 138ms/step - loss: 5.1290e-06 - accuracy: 9.8135e-04 - val_loss: 3.4931e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 5/5 [==============================] - 1s 225ms/step - loss: 5.1505e-06 - accuracy: 9.8135e-04 - val_loss: 3.4932e-04 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 5/5 [==============================] - 2s 447ms/step - loss: 5.1511e-06 - accuracy: 9.8135e-04 - val_loss: 3.4933e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 5/5 [==============================] - 2s 488ms/step - loss: 5.0486e-06 - accuracy: 9.8135e-04 - val_loss: 3.4934e-04 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 5/5 [==============================] - 2s 489ms/step - loss: 4.9967e-06 - accuracy: 9.8135e-04 - val_loss: 3.4935e-04 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 5/5 [==============================] - 1s 214ms/step - loss: 5.0574e-06 - accuracy: 9.8135e-04 - val_loss: 3.4936e-04 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 5/5 [==============================] - 1s 137ms/step - loss: 4.7780e-06 - accuracy: 9.8135e-04 - val_loss: 3.4937e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 5/5 [==============================] - 1s 215ms/step - loss: 4.9956e-06 - accuracy: 9.8135e-04 - val_loss: 3.4938e-04 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 5/5 [==============================] - 1s 230ms/step - loss: 4.8655e-06 - accuracy: 9.8135e-04 - val_loss: 3.4939e-04 - val_accuracy: 0.0000e+00

# %%
score = GRU_model.evaluate(X_test_data, y_test_data) #Evaluate model can be used to get the loss metric.
print('Score: {}'.format(score))
y_pred = GRU_model.predict(X_test_data) #Apply the built model on test data.
y_test_pred = y_scaled_set.inverse_transform(y_pred) #Use inverse transform to undo the scaling that was done before. This gives us the original values.
y_test_actual = y_scaled_set.inverse_transform(y_test_data) # Apply the inverse transform on the actual dataset for easy comparison of predicted vs actual.
# Out:
# 7/7 [==============================] - 0s 12ms/step - loss: 5.7972e-04 - accuracy: 0.0000e+00
# Score: [0.0005797166377305984, 0.0]
# 7/7 [==============================] - 0s 11ms/step

# %%
test_Dates=main_dataset.Date[5100:5303] #create an object which has the dates for the Test data.
